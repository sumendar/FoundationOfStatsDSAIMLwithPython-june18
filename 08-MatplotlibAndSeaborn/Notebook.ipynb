# %% [markdown]
# ## Plotting using pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### plot method

# %% [markdown]
# * built on top of matplotlib
# * work with series and data frame
# * kind argument takes (line, bar, hist, box , ....)
# * pandas dataframe plot work better with wide(aggregated) data

# %%
iris = pd.read_csv("data/iris.csv")
tips = pd.read_csv("data/tips.csv")

# %%
iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %% [markdown]
# **Univariate: Histogram**

# %%
iris['Sepal.Length'].plot(kind='hist')
plt.show()

# %% [markdown]
# **Univariate: Barplot**

# %%
cts = iris['Species'].value_counts()
cts.plot(kind='bar')
plt.show()

# %% [markdown]
# **Bivariate: Scatter plot**

# %%
iris.plot(kind='scatter', x='Sepal.Length', y='Sepal.Width')
plt.show()

# %% [markdown]
# **Bivariate: Boxplots**

# %%
iris.plot(kind='box')
plt.show()

# %% [markdown]
# **Boxplots: comparing categorical vs numerical**

# %%
plt = iris.boxplot(by='Species', column='Sepal.Length')
plt.show()

# %%
data = [['Mike','Jackson',42,500,200],
        ['Jason','Gibbs',52,600,300],
        ['Kolly','Molly',36,700,400],
        ['James','Anderson',24,800,500],
        ['Jack','Wilson',73,900,600],
        ['Peter','Gary',80,950,650]]
df = pd.DataFrame(data,columns=['first_name','last_name','age','savings','expenses'])
print(df)
# Out:
#   first_name last_name  age  savings  expenses
# 0       Mike   Jackson   42      500       200
# 1      Jason     Gibbs   52      600       300
# 2      Kolly     Molly   36      700       400
# 3      James  Anderson   24      800       500
# 4       Jack    Wilson   73      900       600
# 5      Peter      Gary   80      950       650

# %% [markdown]
# * Line plot
# * Scatter plot
# * Box plot
# * Histogram
# * Pie chart
# * Area plot

# %%
df.plot.line();

# %%
df.plot.scatter(x='age',y='savings');

# %%
df.plot.box();

# %%
df.plot.hist();

# %%
df.plot.hist(stacked=True);

# %%
df.savings.plot.hist();

# %%
df.plot.pie(y='age');

# %%
df.plot.area();

# %% [markdown]
# ## Plotting using seaborn

# %% [markdown]
# * **Barplot:** `barplot`
# * **Histograms:** `distplot`
# * **Countplot:** `countplot`
# * **Boxplots:** `boxplot`
# * **Scatter Plot:** `regplot`
# * **Heatmap:** `heatmap`
# * used for colouring points and facets by data
# * seaborn work better with tidy (long) data

# %%
import seaborn as sns
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %% [markdown]
# **seaborn barplot**

# %%
sns.barplot(x="day", y="total_bill", data=tips);
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# **seaborn distplot**

# %%
sns.distplot(iris['Sepal.Length'])
plt.show()

# %% [markdown]
# Visualizing the distribution of a dataset: https://seaborn.pydata.org/tutorial/distributions.html

# %% [markdown]
# **seaborn countplot**

# %%
sns.countplot('Species', data=iris)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-473deb179f49> in <module>()
#       1 sns.countplot('Species', data=iris)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **seaborn boxplot**

# %%
sns.boxplot(x='Species', y='Sepal.Length', data=iris)
plt.show()

# %% [markdown]
# **Seaborn scatterplots**

# %%
sns.regplot(x='Sepal.Length', y='Sepal.Width', data=iris, fit_reg=False)
plt.show()

# %% [markdown]
# **Seaborn heatmap**

# %% [markdown]
# * A heatmap contains values representing various shades of the same colour for each value to be plotted.
# * Usually the darker shades of the chart represent higher values than the lighter shade.

# %%
index = ['aaa', 'bbb','ccc','ddd','eee']
cols = ['A', 'B', 'C','D']
dfh = pd.DataFrame(abs(np.random.randn(5,4)), index=index, columns=cols)

# %%
print(dfh)
sns.heatmap(dfh,annot=True);
# Out:
#             A         B         C         D
# aaa  1.751982  0.624015  0.470069  1.459622
# bbb  1.065575  1.050336  0.796435  1.003526
# ccc  0.772839  0.427251  1.028596  0.709900
# ddd  0.071301  0.239773  0.515498  0.177009
# eee  0.530386  0.531830  0.135647  0.336613

# %% [markdown]
# <span style="color:red; font-family:Comic Sans MS">follow along</span>
# https://www.absentdata.com/python-graphs/create-a-heat-map-with-seaborn/
# https://elitedatascience.com/python-seaborn-tutorial

# %% [markdown]
# https://stackabuse.com/seaborn-library-for-data-visualization-in-python-part-1/
# https://stackabuse.com/seaborn-library-for-data-visualization-in-python-part-2/

# %% [markdown]
# ## Plotting using matplotlib

# %% [markdown]
# <span style="color:red; font-family:Comic Sans MS">Resources: </span>
# <a href="https://github.com/codebasics/py/tree/master/matpltlib" target="_blank">https://github.com/codebasics/py/tree/master/matpltlib</a>
# https://heartbeat.fritz.ai/introduction-to-matplotlib-data-visualization-in-python-d9143287ae39
# https://www.listendata.com/2019/06/matplotlib-tutorial-learn-plot-python.html

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(5,5, 'o')
plt.show()

# %%
plt.plot(range(10))
plt.show()

# %%
plt.plot(range(10), 'r+')
plt.show()

# %%
x =[0,1,2,3,4,5]
y = [0,10,20,30,40,50]
plt.plot(x,y)
plt.show()

# %%
import numpy as np
x = np.arange(0,100)
y = 9 * x + 7
plt.plot(x,y)
plt.show()

# %%
plt.hist(iris['Sepal.Length']) # is nothing but iris['Sepal.Length'].plot.hist() or iris['Sepal.Length'].plot(kind='hist')
plt.show()

# %%
plt.scatter(iris['Sepal.Length'], iris['Sepal.Width'])
plt.show()

# %% [markdown]
# **Python charts tutorial with Matplotlib**
# http://www.datasciencemadesimple.com/python-charts-tutorial-with-matplotlib/

# %% [markdown]
# ### Ananomy of figure (parts of figure) ##

# %% [markdown]
# ![Imgur](https://i.imgur.com/WG26Ib7.png)

# %% [markdown]
# * `figure` - Entire image
# * `Axes` - referred as subplot in that image (a figure has one or more `Axes`)
# * `Axis`
# *  Different plotting functions return different objects, some return only figures some of return only `Axes`

# %% [markdown]
# http://www.aosabook.org/en/matplotlib.html

# %% [markdown]
# ### Figures and axes

# %% [markdown]
# ![Imgur](https://i.imgur.com/EJFJo7r.png)

# %%
#creating one Axes using subplot function
fig, ax = plt.subplots()
ax.scatter(iris['Sepal.Length'], iris['Sepal.Width'])
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(iris['Sepal.Length'], iris['Sepal.Width'])
ax.set_title('Sepal Length vs Sepal Width')
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
plt.show()

# %% [markdown]
# ### Simple line plot

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load iris data
iris = sns.load_dataset("iris")

# Construct iris plot
sns.swarmplot(x="species", y="petal_length", data=iris)

# Show plot
plt.show()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %% [markdown]
# ### Line Plot

# %%
# import external libraries
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Sample Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

# Note that using plt.subplots below is equivalent to using
# fig = plt.figure() and then ax = fig.add_subplot(111)
fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
title='About as simple as it gets, folks')
ax.grid()

plt.show()

# %% [markdown]
# ### Histograms

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

# example data
mu = 100 # mean of distribution
sigma = 15 # standard deviation of distribution
x = mu + sigma * np.random.randn(437)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins)

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--')
ax.set_xlabel('Smarts')
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()

# %% [markdown]
# * Use `tight_layout()` function while plotting multiple sub plots, so that the figure axes do not overlap
# * Use `clf()` function to clear the figure to prevent overaping one on another

# %% [markdown]
# ### Bar Charts

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N) # the x locations for the groups
width = 0.35 # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %% [markdown]
# ### Pie Chart

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# Prepare your data
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
fracs = [15, 30, 45, 10]

#Draw Pie chart
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)

plt.show()

# %%
import matplotlib.pyplot as plt
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]
plt.pie(exp_vals,labels=exp_labels)
plt.show()

# %%
plt.pie(exp_vals,labels=exp_labels, shadow=True)
plt.axis("equal")
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2 # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
#creating two Axes using subplot function
fig, (ax1, ax2) = plt.subplots(1, 2) # here the figure has 1 row 2 columns
ax1.scatter(iris['Sepal.Length'], iris['Sepal.Width'])
ax2.hist(iris['Sepal.Length'])
plt.show()

# %%
# import external libraries
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Sample Data for plotting
x = np.linspace(0, 5, 11)
y = x ** 2

plt.subplot(1, 2, 1)
plt.plot(x, y, 'r--')
plt.subplot(1, 2, 2)
plt.plot(y, x, 'g*-')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

# %%
plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(19680801)
data = np.random.randn(2, 100)

fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs[0, 0].hist(data[0])
axs[1, 0].scatter(data[0], data[1])
axs[0, 1].plot(data[0], data[1])
axs[1, 1].hist2d(data[0], data[1])

plt.show()

# %% [markdown]
# ### Multiple subplots in one figure
# https://pbpython.com/effective-matplotlib.html

# %% [markdown]
# ![Imgur](https://i.imgur.com/dtPTkgz.png)

# %% [markdown]
# **Other Packages**
# ggplot2:
# http://ggplot.yhathq.com/
# Bokeh:
# https://bokeh.pydata.org/en/latest/
# pygal:
# http://pygal.org/en/stable/
# plot.ly:
# https://plot.ly/python/
# https://stackabuse.com/using-plotly-library-for-interactive-data-visualization-in-python/

# %% [markdown]
# **courses:**
# https://www.coursera.org/learn/python-for-data-visualization
# https://www.coursera.org/learn/python-plotting/home/welcome

# %% [markdown]
# <span style="color:red; font-family:Comic Sans MS">**Sources & References**</span>
# <a href="http://pbpython.com/effective-matplotlib.html" target="_blank">http://pbpython.com/effective-matplotlib.html</a>
# <a href="https://www.youtube.com/watch?v=_YWwU-gJI5U&fbclidNpPQ" target="_blank">https://www.youtube.com/watch?v=_YWwU-gJI5U&fbclidNpPQ</a>
# <a href="https://engmrk.com/module6-introduction-to-matplotlib-v2/" target="_blank">https://engmrk.com/module6-introduction-to-matplotlib-v2/</a>
# <a href="https://engmrk.com/module7-introduction-to-seaborn/" target="_blank">https://engmrk.com/module7-introduction-to-seaborn/</a>
# <a href="https://elitedatascience.com/python-seaborn-tutorial" target="_blank">https://elitedatascience.com/python-seaborn-tutorial</a>
# https://www.analyticsvidhya.com/blog/2015/05/data-visualization-python/
#
# <a href="https://campus.datacamp.com/courses/python-for-r-users/" target="_blank">https://campus.datacamp.com/courses/python-for-r-users/</a>
# <a href="https://realpython.com/python-matplotlib-guide/" target="_blank">https://realpython.com/python-matplotlib-guide/</a>
# <a href="https://www.tutorialspoint.com/numpy/numpy_matplotlib.htm" target="_blank">https://www.tutorialspoint.com/numpy/numpy_matplotlib.htm</a>
# <a href="https://www.tutorialspoint.com/python_pandas/python_pandas_visualization.htm" target="_blank">https://www.tutorialspoint.com/python_pandas/python_pandas_visualization.htm</a>
# <a href="https://pythonspot.com/en/matplotlib" target="_blank">https://pythonspot.com/en/matplotlib</a>
